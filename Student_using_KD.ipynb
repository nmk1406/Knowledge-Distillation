# %% [markdown]
# <a href="https://colab.research.google.com/github/nmk1406/Knowledge-Distillation/blob/main/Student_using_KD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check GPU Colab

# %%
# !nvidia-smi
# Out:
# Tue Jul 18 02:36:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Install Torch = 1.12.1, Torchvision = 0.13.1

# %%
# !pip install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 65.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 81.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.2+cu118
#     Uninstalling torchaudio-2.0.2+cu118:
#       Successfully uninstalled torchaudio-2.0.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# install torchdistill

# %%
# !pip install torchdistill
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 4.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# Clone repository from github

# %%
# !git clone https://github.com/nmk1406/Knowledge-Distillation.git
# Out:
# Cloning into 'Knowledge-Distillation'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 103 (delta 2), reused 0 (delta 0), pack-reused 95
# Receiving objects: 100% (103/103), 132.32 KiB | 1.81 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %% [markdown]
# Hyperparameter tuning based on train:val = 45k:5k

# %%
# !python Knowledge-Distillation/examples/image_classification.py --config Knowledge-Distillation/configs/kd/resnet20_from_densenet_bc_k12_depth100-hyperparameter_tuning.yaml --log log/cifar10/kd/resnet20_from_densenet_bc_k12_depth100-hyperparameter_tuning.log
# Out:
# 2023/07/17 23:39:45	INFO	torchdistill.common.main_util	Not using distributed mode
# 2023/07/17 23:39:45	INFO	__main__	Namespace(config='Knowledge-Distillation/configs/kd/resnet20_from_densenet_bc_k12_depth100-hyperparameter_tuning.yaml', device='cuda', log='log/cifar10/kd/resnet20_from_densenet_bc_k12_depth100-hyperparameter_tuning.log', start_epoch=0, seed=None, test_only=False, student_only=False, log_config=False, world_size=1, dist_url='env://', adjust_lr=False)
# 2023/07/17 23:39:45	INFO	torchdistill.datasets.util	Loading dummy data
# ...
# 100% 170498071/170498071 [00:13<00:00, 12972057.90it/s]
# Extracting ./resource/dataset/cifar10/cifar-10-python.tar.gz to ./resource/dataset/cifar10
# 2023/07/17 23:40:03	INFO	torchdistill.datasets.util	Splitting `dummy` dataset (50000 samples in total)
# 2023/07/17 23:40:03	INFO	torchdistill.datasets.util	new dataset_id: `cifar10/train` (45000 samples)
# ...

# %% [markdown]
# Final run with hyperparameters determinded by the above hyperparameter-tuning

# %%
# !python Knowledge-Distillation/examples/image_classification.py --config Knowledge-Distillation/configs/kd/resnet20_from_densenet_bc_k12_depth100-final_run.yaml --log log/cifar10/kd/resnet20_from_densenet_bc_k12_depth100-final_run.log
# Out:
# 2023/07/18 02:38:09	INFO	torchdistill.common.main_util	Not using distributed mode
# 2023/07/18 02:38:09	INFO	__main__	Namespace(config='Knowledge-Distillation/configs/kd/resnet20_from_densenet_bc_k12_depth100-final_run.yaml', device='cuda', log='log/cifar10/kd/resnet20_from_densenet_bc_k12_depth100-final_run.log', start_epoch=0, seed=None, test_only=False, student_only=False, log_config=False, world_size=1, dist_url='env://', adjust_lr=False)
# 2023/07/18 02:38:09	INFO	torchdistill.datasets.util	Loading train data
# ...
# 100% 170498071/170498071 [00:01<00:00, 103653861.68it/s]
# Extracting ./resource/dataset/cifar10/cifar-10-python.tar.gz to ./resource/dataset/cifar10
# 2023/07/18 02:38:15	INFO	torchdistill.datasets.util	dataset_id `cifar10/train`: 5.997677803039551 sec
# 2023/07/18 02:38:15	INFO	torchdistill.datasets.util	Loading val data
# Files already downloaded and verified
# 2023/07/18 02:38:15	INFO	torchdistill.datasets.util	dataset_id `cifar10/val`: 0.6991043090820312 sec
# ...
